# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in /opt/conda/miniconda3/lib/python3.8/site-packages (2.8.6)

# %%
# connection
# %load_ext sql
# %sql postgresql://postgres:translate@10.97.16.10/db-dvd
# Out:
# 'Connected: postgres@db-dvd'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %%sql dvd_cust <<
#
# SELECT
#     CONCAT(first_name, ' ', last_name) AS customer_name,
#     SUM(p.amount) AS total_amount
# FROM
#     customer AS c
# FULL JOIN
#     payment AS p
# ON
#     c.customer_id = p.customer_id
# GROUP BY
#     c.first_name, c.last_name
# ORDER BY total_amount desc
# LIMIT 5
# Out:
#  * postgresql://postgres:***@10.97.16.10/db-dvd
# 5 rows affected.
# Returning data to local variable dvd_cust

# %%
# convert the query result into dataframe
dvd_cust_df = dvd_cust.DataFrame()
dvd_cust_df
# Out:
#     customer_name total_amount
# 0    Eleanor Hunt       211.55
# 1       Karl Seal       208.58
# 2   Marion Snyder       194.61
# 3  Rhonda Kennedy       191.62
# 4      Clara Shaw       189.60

# %%
dvd_cust_df2 = dvd_cust_df.sort_values('total_amount', ascending=True)
dvd_cust_df2
# Out:
#     customer_name total_amount
# 4      Clara Shaw       189.60
# 3  Rhonda Kennedy       191.62
# 2   Marion Snyder       194.61
# 1       Karl Seal       208.58
# 0    Eleanor Hunt       211.55

# %%
ta = dvd_cust_df2['total_amount']
cn = dvd_cust_df2['customer_name']

plt.barh(cn,
         ta,
         color=['#E297AF', '#BD5E7C','#973253','#711331','#4b0018'])
plt.title('Top 5 The Most Spending Customer')
plt.xlabel('Total Amount')
plt.ylabel('Customer Name')
plt.show()

# %%
# %%sql dvd_sta <<
#
# SELECT
#     staff_id,
#     COUNT(payment_id)
# FROM
#     payment
# GROUP BY
#     staff_id
# Out:
#  * postgresql://postgres:***@10.97.16.10/db-dvd
# 2 rows affected.
# Returning data to local variable dvd_sta

# %%
# convert the query result into dataframe
dvd_sta_df = dvd_sta.DataFrame()
dvd_sta_df
# Out:
#    staff_id  count
# 0         1   7292
# 1         2   7304

# %%
values = dvd_sta_df['count']
label = dvd_sta_df['staff_id']
pastel = ['#FFAB89', '#5EB08D']


plt.pie(values,
        labels =label,
        colors = pastel,
        startangle = 90,
        autopct='%1.1f%%')
plt.show()

# %%
# %%sql dvd_rat <<
#
# SELECT
#     rating,
#     COUNT(DISTINCT(film_id)) AS count_film
# FROM
#     film
# GROUP BY
#     rating
# Out:
#  * postgresql://postgres:***@10.97.16.10/db-dvd
# 5 rows affected.
# Returning data to local variable dvd_rat

# %%
# convert the query result into dataframe
dvd_rat_df = dvd_rat.DataFrame()
dvd_rat_df
# Out:
#   rating  count_film
# 0      G         178
# 1     PG         194
# 2  PG-13         223
# 3      R         195
# 4  NC-17         210

# %%
values = dvd_rat_df['count_film']
label = dvd_rat_df['rating']
pastel = ['#CAF7E3','#EDFFEC', '#f6dfeb', '#e4bad4', '#E2D5D5', '#BBBBBB']


plt.pie(values,
        labels =label,
        colors = pastel,
        startangle = 90,
        autopct='%1.1f%%')
plt.show()

# %%
# %%sql dvd_date <<
#
# SELECT
#     DATE (rental_date) as date,
#     COUNT(DISTINCT(rental_id))
# FROM
#     rental
# GROUP BY
#     date
# ORDER BY
#     date asc
# Out:
#  * postgresql://postgres:***@10.97.16.10/db-dvd
# 41 rows affected.
# Returning data to local variable dvd_date

# %%
# convert the query result into dataframe
dvd_date_df = dvd_date.DataFrame()
dvd_date_df.head()
# Out:
#          date  count
# 0  2005-05-24      8
# 1  2005-05-25    137
# 2  2005-05-26    174
# 3  2005-05-27    166
# 4  2005-05-28    196

# %%
dvd_date_df['date'] = pd.to_datetime(dvd_date_df['date'])

# %%
dvd_date_df['month'] = dvd_date_df['date'].dt.month

# %%
dvd_date_df.head()
# Out:
#         date  count  month
# 0 2005-05-24      8      5
# 1 2005-05-25    137      5
# 2 2005-05-26    174      5
# 3 2005-05-27    166      5
# 4 2005-05-28    196      5

# %%
most = dvd_date_df.groupby('month')['count'].agg(sum)
most.head()
# Out:
# month
# 2     182
# 5    1156
# 6    2311
# 7    6709
# 8    5686
# Name: count, dtype: int64

# %%
most.plot.bar(color="#8A7218")
plt.show()
