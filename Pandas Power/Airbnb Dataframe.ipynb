# %% [markdown]
# # GET READY WITH THE DATASET

# %% [markdown]
# ## 1. Import Dataset

# %% [markdown]
# ### 1.1. Install Pandas

# %% [raw]
# !pip install pandas

# %% [markdown]
# ### 1.2. Import Pandas

# %%
import pandas as pd

# %% [markdown]
# ### 1.3. Import Dataset

# %% [markdown]
# ## 2. Retrieve Dataset

# %% [markdown]
# ### 2.1. First n Rows using .head()

# %%
df = pd.read_csv(r"D:\nabila\jupyter\Untitled Folder\AB_NYC_2019\AB_NYC_20192.csv")

# %%
df.head(5)
# Out:
#        id                                              name  host_id  \
# 0  2539.0                Clean & quiet apt home by the park   2787.0
# 1  2595.0                             Skylit Midtown Castle   2845.0
# 2  3647.0               THE VILLAGE OF HARLEM....NEW YORK !   4632.0
# 3  3831.0                   Cozy Entire Floor of Brownstone   4869.0
# 4  5022.0  Entire Apt: Spacious Studio/Loft by central park   7192.0
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### 2.2. Last n Rows using .tail()

# %%
df.tail()
# Out:
#                id                                               name  \
# 48897  36484665.0    Charming one bedroom - newly renovated rowhouse
# 48898  36485057.0      Affordable room in Bushwick/East Williamsburg
# 48899  36485431.0            Sunny Studio at Historical Neighborhood
# 48900  36485609.0               43rd St. Time Square-cozy single bed
# 48901  36487245.0  Trendy duplex in the very heart of Hell's Kitchen
#
#           host_id      host_name neighbourhood_group       neighbourhood  \
# 48897   8232441.0        Sabrina            Brooklyn  Bedford-Stuyvesant
# 48898   6570630.0        Marisol            Brooklyn            Bushwick
# 48899  23492952.0  Ilgar & Aysel           Manhattan              Harlem
# 48900  30985759.0            Taz           Manhattan      Hell's Kitchen
# 48901  68119814.0     Christophe           Manhattan      Hell's Kitchen
#
#        latitude  longitude        room_type  price  minimum_nights  \
# ...

# %% [markdown]
# ### 2.3. Random n Rows using .sample()

# %%
df.sample(5)
# Out:
#                id                                               name  \
# 33485  26472079.0        Cozy studio at UWS near Columbia university
# 14491  11398939.0                 Stay in Private Room in PARK SLOPE
# 25176  20164634.0    Quiet 1BR in Ft Greene! Close to Ft Greene park
# 1286     552141.0    Historic sundrenched apt of the Lower East Side
# 9827    7560654.0  Beautiful 1BR in upper Manhattan- close to sub...
#
#           host_id       host_name neighbourhood_group        neighbourhood  \
# 33485    274910.0           Yooin           Manhattan  Morningside Heights
# 14491   4218873.0       Elizabeth            Brooklyn          Sunset Park
# 25176  12586279.0          Sophia            Brooklyn          Fort Greene
# 1286    2712998.0            Greg           Manhattan      Lower East Side
# 9827   22863142.0  Sarah And Mike           Manhattan   Washington Heights
#
#        latitude  longitude        room_type  price  minimum_nights  \
# ...

# %% [markdown]
# ### 2.4. Retrieve specific Row

# %%
df[3:8]
# Out:
#        id                                              name  host_id  \
# 3  3831.0                   Cozy Entire Floor of Brownstone   4869.0
# 4  5022.0  Entire Apt: Spacious Studio/Loft by central park   7192.0
# 5  5099.0         Large Cozy 1 BR Apartment In Midtown East   7322.0
# 6  5121.0                                   BlissArtsSpace!   7356.0
# 7  5178.0                  Large Furnished Room Near B'way    8967.0
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 3  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan         East Harlem  40.79851  -73.94399
# 5        Chris           Manhattan         Murray Hill  40.74767  -73.97500
# 6        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 7     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ## 3. Data Frame Info

# %% [markdown]
# ### 3.1. Type of Data the object

# %%
df.head()
# Out:
#        id                                              name  host_id  \
# 0  2539.0                Clean & quiet apt home by the park   2787.0
# 1  2595.0                             Skylit Midtown Castle   2845.0
# 2  3647.0               THE VILLAGE OF HARLEM....NEW YORK !   4632.0
# 3  3831.0                   Cozy Entire Floor of Brownstone   4869.0
# 4  5022.0  Entire Apt: Spacious Studio/Loft by central park   7192.0
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 3.2. Get Data Dimension using .shape()

# %%
df.shape
# Out:
# (48902, 16)

# %% [markdown]
# ### 3.3. Data Frame Information using .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48902 entries, 0 to 48901
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48901 non-null  float64
#  1   name                            48885 non-null  object
#  2   host_id                         48901 non-null  float64
#  3   host_name                       48881 non-null  object
#  4   neighbourhood_group             48902 non-null  object
#  5   neighbourhood                   48902 non-null  object
#  6   latitude                        48901 non-null  float64
#  7   longitude                       48901 non-null  float64
#  8   room_type                       48901 non-null  object
#  9   price                           48901 non-null  float64
#  10  minimum_nights                  48901 non-null  float64
#  11  number_of_reviews               48901 non-null  float64
# ...

# %% [markdown]
# ### 3.4. Data Frame Information using .describe()

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.890100e+04  4.890100e+04  48901.000000  48901.000000  48901.000000
# mean   1.901574e+07  6.761376e+07     40.728947    -73.952167    152.721539
# std    1.098390e+07  7.860916e+07      0.054530      0.046162    240.141978
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.470554e+06  7.813520e+06     40.690090    -73.983070     69.000000
# 50%    1.967630e+07  3.079133e+07     40.723070    -73.955680    106.000000
# 75%    2.915204e+07  1.074344e+08     40.763110    -73.936280    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48901.000000       48901.000000       38849.000000
# mean         7.029365          23.279769           1.373159
# std         20.509364          44.560768           1.680355
# ...

# %% [markdown]
# # DATA PRE-PROCESSING

# %% [markdown]
# ## 1. Cek Duplicate Values

# %% [markdown]
# ### 1.1. .duplicated()and .drop_duplicates()

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48897    False
# 48898    False
# 48899    False
# 48900    False
# 48901    False
# Length: 48902, dtype: bool

# %%
df.duplicated(subset=None, keep='first').sum()
# Out:
# 6

# %%
df.duplicated(subset=None, keep=False).value_counts()
# Out:
# False    48890
# True        12
# dtype: int64

# %%
df[df.duplicated(keep=False)]
# Out:
#                id                                               name  \
# 23         8110.0                              CBG Helps Haiti Rm #2
# 24         8110.0                              CBG Helps Haiti Rm #2
# 47        12937.0  1 Stop fr. Manhattan! Private Suite,Landmark B...
# 48        12937.0  1 Stop fr. Manhattan! Private Suite,Landmark B...
# 68        16458.0  Light-filled 2B duplex in the heart of Park Sl...
# 69        16458.0  Light-filled 2B duplex in the heart of Park Sl...
# 100       21644.0                          Upper Manhattan, New York
# 101       21644.0                          Upper Manhattan, New York
# 19252  15328242.0                  PRIVATE BED ROOM 12 MINS FROM JFK
# 19253  15328242.0                  PRIVATE BED ROOM 12 MINS FROM JFK
# 37713  29885196.0          Airy Brooklyn Limestone:  2 bedroom suite
# 37714  29885196.0          Airy Brooklyn Limestone:  2 bedroom suite
#
# ...

# %%
df1_no_duplicate= df.drop_duplicates()
df1_no_duplicate.head(3)
# Out:
#        id                                 name  host_id  host_name  \
# 0  2539.0   Clean & quiet apt home by the park   2787.0       John
# 1  2595.0                Skylit Midtown Castle   2845.0   Jennifer
# 2  3647.0  THE VILLAGE OF HARLEM....NEW YORK !   4632.0  Elisabeth
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0  149.0             1.0                9.0  2018-10-19               0.21
# 1  225.0             1.0               45.0  2019-05-21               0.38
# 2  150.0             3.0                0.0         NaN                NaN
#
#    calculated_host_listings_count  availability_365
# ...

# %%
df1_no_duplicate.shape
# Out:
# (48896, 16)

# %%
df.shape
# Out:
# (48902, 16)

# %% [markdown]
# ## 2. Check Missing Values

# %% [markdown]
# ### 2.1. Using .isnul()

# %%
#cek missing value (every column)
df1_no_duplicate.isnull().sum(axis=0)
#axis = 0: sepanjang baris
# Out:
# id                                    1
# name                                 17
# host_id                               1
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              1
# longitude                             1
# room_type                             1
# price                                 1
# minimum_nights                        1
# number_of_reviews                     1
# last_review                       10053
# reviews_per_month                 10053
# calculated_host_listings_count        1
# availability_365                      1
# dtype: int64

# %%
df1_no_duplicate[df1_no_duplicate.isnull().any(axis=1)]
# Out:
#                id                                               name  \
# 2          3647.0                THE VILLAGE OF HARLEM....NEW YORK !
# 19         7750.0                  Huge 2 BR Upper East  Cental Park
# 27         8700.0  Magnifique Suite au N de Manhattan - vue Cloitres
# 37        11452.0                        Clean and Quiet in Brooklyn
# 39        11943.0                          Country space in the city
# ...           ...                                                ...
# 48897  36484665.0    Charming one bedroom - newly renovated rowhouse
# 48898  36485057.0      Affordable room in Bushwick/East Williamsburg
# 48899  36485431.0            Sunny Studio at Historical Neighborhood
# 48900  36485609.0               43rd St. Time Square-cozy single bed
# 48901  36487245.0  Trendy duplex in the very heart of Hell's Kitchen
#
#           host_id        host_name neighbourhood_group       neighbourhood  \
# ...

# %%
df2_no_missingvalue = df1_no_duplicate.dropna()
df2_no_missingvalue.head(3)
# Out:
#        id                                name  host_id    host_name  \
# 0  2539.0  Clean & quiet apt home by the park   2787.0         John
# 1  2595.0               Skylit Midtown Castle   2845.0     Jennifer
# 3  3831.0     Cozy Entire Floor of Brownstone   4869.0  LisaRoxanne
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0  149.0             1.0                9.0  2018-10-19               0.21
# 1  225.0             1.0               45.0  2019-05-21               0.38
# 3   89.0             1.0              270.0  2019-07-05               4.64
#
#    calculated_host_listings_count  availability_365
# ...

# %%
df2_no_missingvalue.isnull().sum(axis=0)
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df2_no_missingvalue.shape
# Out:
# (38821, 16)

# %%
df1_no_duplicate.shape
# Out:
# (48896, 16)

# %% [markdown]
# # FEATURE ENGINEERING

# %% [markdown]
# ## 1. Copy Data Frame

# %%
df3 = df2_no_missingvalue.copy()
df3.head(4)
# Out:
#        id                                              name  host_id  \
# 0  2539.0                Clean & quiet apt home by the park   2787.0
# 1  2595.0                             Skylit Midtown Castle   2845.0
# 3  3831.0                   Cozy Entire Floor of Brownstone   4869.0
# 4  5022.0  Entire Apt: Spacious Studio/Loft by central park   7192.0
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room  149.0             1.0                9.0  2018-10-19
# 1  Entire home/apt  225.0             1.0               45.0  2019-05-21
# ...

# %% [markdown]
# ## 2. Get a List of Values

# %% [markdown]
# ### 2.1.  All Value List (in a column)

# %%
df3["neighbourhood_group"].tolist()
# Out:
# ['Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Queens',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Brooklyn',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Brooklyn',
# ...

# %% [markdown]
# ### 2.2.  Unique Value List (in a column)

# %%
df3_1 = list(df3["neighbourhood_group"].unique())
df3_1
# Out:
# ['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx']

# %%
len(df3_1)
# Out:
# 5

# %% [markdown]
# ### 2.2.  Column as a List

# %%
df3.columns.tolist()
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365']

# %% [markdown]
# ## 3. Create New Data Frame from a subset of columns

# %% [markdown]
# ### 3.1.  Select Specified Columns

# %%
df4 = df3[["name","neighbourhood_group", "price"]]
df4.head()
# Out:
#                                                name neighbourhood_group  price
# 0                Clean & quiet apt home by the park            Brooklyn  149.0
# 1                             Skylit Midtown Castle           Manhattan  225.0
# 3                   Cozy Entire Floor of Brownstone            Brooklyn   89.0
# 4  Entire Apt: Spacious Studio/Loft by central park           Manhattan   80.0
# 5         Large Cozy 1 BR Apartment In Midtown East           Manhattan  200.0

# %%
df3.head(3)
# Out:
#        id                                name  host_id    host_name  \
# 0  2539.0  Clean & quiet apt home by the park   2787.0         John
# 1  2595.0               Skylit Midtown Castle   2845.0     Jennifer
# 3  3831.0     Cozy Entire Floor of Brownstone   4869.0  LisaRoxanne
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0  149.0             1.0                9.0  2018-10-19               0.21
# 1  225.0             1.0               45.0  2019-05-21               0.38
# 3   89.0             1.0              270.0  2019-07-05               4.64
#
#    calculated_host_listings_count  availability_365
# ...

# %% [markdown]
# ### 3.2.  Drop Specified Columns

# %%
df5 = df3.drop(["host_id", "host_name"], axis=1)
df5.head(3)
#axis=1 : removing column
# Out:
#        id                                name neighbourhood_group  \
# 0  2539.0  Clean & quiet apt home by the park            Brooklyn
# 1  2595.0               Skylit Midtown Castle           Manhattan
# 3  3831.0     Cozy Entire Floor of Brownstone            Brooklyn
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0    Kensington  40.64749  -73.97237     Private room  149.0             1.0
# 1       Midtown  40.75362  -73.98377  Entire home/apt  225.0             1.0
# 3  Clinton Hill  40.68514  -73.95976  Entire home/apt   89.0             1.0
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                9.0  2018-10-19               0.21
# 1               45.0  2019-05-21               0.38
# 3              270.0  2019-07-05               4.64
#
#    calculated_host_listings_count  availability_365
# 0                             6.0             365.0
# 1                             2.0             355.0
# ...

# %% [markdown]
# ### 3.3.  Delete List using Loop For and List

# %%
df3_1
# Out:
# ['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx']

# %%
deleted_neighbourhood_group = ['Brooklyn', 'Manhattan']
update_neighbourhood_group = [[i for i in df3_1 if i not in deleted_neighbourhood_group]]
update_neighbourhood_group
# Out:
# [['Queens', 'Staten Island', 'Bronx']]

# %% [markdown]
# ## 4. Lower Case

# %%
df5_1 = df5.apply(lambda x: x.astype(str).str.lower())
df5_1.head()
# Out:
#        id                                              name  \
# 0  2539.0                clean & quiet apt home by the park
# 1  2595.0                             skylit midtown castle
# 3  3831.0                   cozy entire floor of brownstone
# 4  5022.0  entire apt: spacious studio/loft by central park
# 5  5099.0         large cozy 1 br apartment in midtown east
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            brooklyn    kensington  40.64749  -73.97237     private room
# 1           manhattan       midtown  40.75362  -73.98377  entire home/apt
# 3            brooklyn  clinton hill  40.68514  -73.95976  entire home/apt
# 4           manhattan   east harlem  40.79851  -73.94399  entire home/apt
# 5           manhattan   murray hill  40.74767    -73.975  entire home/apt
#
#    price minimum_nights number_of_reviews last_review reviews_per_month  \
# 0  149.0            1.0               9.0  2018-10-19              0.21
# ...

# %% [markdown]
# ## 5. Combine Data Frame

# %% [markdown]
# ### 5.1. Concatenate data frames

# %%
df6 = df4[0:3]
df7 = df4[4:6]

# %%
df6
# Out:
#                                  name neighbourhood_group  price
# 0  Clean & quiet apt home by the park            Brooklyn  149.0
# 1               Skylit Midtown Castle           Manhattan  225.0
# 3     Cozy Entire Floor of Brownstone            Brooklyn   89.0

# %%
df7
# Out:
#                                         name neighbourhood_group  price
# 5  Large Cozy 1 BR Apartment In Midtown East           Manhattan  200.0
# 6                            BlissArtsSpace!            Brooklyn   60.0

# %%
pd.concat([df6, df7], ignore_index=True)
# Out:
#                                         name neighbourhood_group  price
# 0         Clean & quiet apt home by the park            Brooklyn  149.0
# 1                      Skylit Midtown Castle           Manhattan  225.0
# 2            Cozy Entire Floor of Brownstone            Brooklyn   89.0
# 3  Large Cozy 1 BR Apartment In Midtown East           Manhattan  200.0
# 4                            BlissArtsSpace!            Brooklyn   60.0

# %% [markdown]
# ### 5.2. Merge data frames

# %%
discount = pd.read_csv(r"D:\nabila\jupyter\Untitled Folder\AB_NYC_2019\AB_NYC_2019_discount.csv")

# %%
discount
# Out:
#   neighbourhood_group   discount
# 0            Brooklyn       0.10
# 1           Manhattan       0.00
# 2              Queens       0.50
# 3              Staten       0.15
# 4              Island       0.20
# 5               Bronx       0.25

# %%
df4.head()
# Out:
#                                                name neighbourhood_group  price
# 0                Clean & quiet apt home by the park            Brooklyn  149.0
# 1                             Skylit Midtown Castle           Manhattan  225.0
# 3                   Cozy Entire Floor of Brownstone            Brooklyn   89.0
# 4  Entire Apt: Spacious Studio/Loft by central park           Manhattan   80.0
# 5         Large Cozy 1 BR Apartment In Midtown East           Manhattan  200.0

# %%
df8_merge= pd.merge(df4, discount, on ="neighbourhood_group")
df8_merge
# Out:
#                                                   name neighbourhood_group  \
# 0                   Clean & quiet apt home by the park            Brooklyn
# 1                      Cozy Entire Floor of Brownstone            Brooklyn
# 2                                      BlissArtsSpace!            Brooklyn
# 3       Lovely Room 1, Garden, Best Area, Legal rental            Brooklyn
# 4                     Only 2 stops to Manhattan studio            Brooklyn
# ...                                                ...                 ...
# 38502                                 The Emperors Den               Bronx
# 38503  Great Apartment only $79 per night \nGreat area               Bronx
# 38504            Bright and Sunny home away from home.               Bronx
# 38505                  Best 1 bedroom apartment in NYC               Bronx
# 38506                    1B-1B apartment near by Metro               Bronx
#
#        price   discount
# 0      149.0       0.10
# ...

# %% [markdown]
# ## 6. Filtering

# %% [markdown]
# ### 6.1. By Row

# %% [markdown]
# #### 6.1.1. Using == (single and multiple condition)

# %% [markdown]
# 6.1.1.1. Single Condition

# %%
df4_2 = df4.copy()

# %%
df4_2.head(3)
# Out:
#                                  name neighbourhood_group  price
# 0  Clean & quiet apt home by the park            Brooklyn  149.0
# 1               Skylit Midtown Castle           Manhattan  225.0
# 3     Cozy Entire Floor of Brownstone            Brooklyn   89.0

# %%
df4_2[df4_2["neighbourhood_group"] == 'Bronx']
# Out:
#                                                     name neighbourhood_group  \
# 175                                     Room with a View               Bronx
# 211                       Cozy bedroom by Yankee Stadium               Bronx
# 265     DOMINIQUE'S NY mini efficiency* wifi*metro*quiet               Bronx
# 313                 Condo Apartment with laundry in unit               Bronx
# 437    Artsy 1 bedroom Apt. 20 min to 42nd Grand Cent...               Bronx
# ...                                                  ...                 ...
# 48075                                   The Emperors Den               Bronx
# 48082    Great Apartment only $79 per night \nGreat area               Bronx
# 48153              Bright and Sunny home away from home.               Bronx
# 48347                    Best 1 bedroom apartment in NYC               Bronx
# 48812                      1B-1B apartment near by Metro               Bronx
#
#        price
# 175     40.0
# 211     45.0
# ...

# %% [markdown]
# 6.1.1.2. Multiple Condition

# %%
condition = (df4_2["neighbourhood_group"] == 'Bronx') & (df4_2["price"] < 50)

# %%
df4_2[condition]
# Out:
#                                                name neighbourhood_group  price
# 175                                Room with a View               Bronx   40.0
# 211                  Cozy bedroom by Yankee Stadium               Bronx   45.0
# 488                              Affordable & Cozy                Bronx   37.0
# 649               NY/ Big Room for 2 near Manhattan               Bronx   42.0
# 1064                comfy room minutes from museums               Bronx   49.0
# ...                                             ...                 ...    ...
# 47724  Get away Private Bedroom in New York City #6               Bronx   39.0
# 47797                       Nice house private room               Bronx   40.0
# 48036                           Nice room to rent 1               Bronx   40.0
# 48040     Nice house room 2 near van cortlandt park               Bronx   40.0
# 48153         Bright and Sunny home away from home.               Bronx   40.0
#
# [273 rows x 3 columns]

# %% [markdown]
# #### 6.1.2. using .isin()

# %%
df3.head(3)
# Out:
#        id                                name  host_id    host_name  \
# 0  2539.0  Clean & quiet apt home by the park   2787.0         John
# 1  2595.0               Skylit Midtown Castle   2845.0     Jennifer
# 3  3831.0     Cozy Entire Floor of Brownstone   4869.0  LisaRoxanne
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0  149.0             1.0                9.0  2018-10-19               0.21
# 1  225.0             1.0               45.0  2019-05-21               0.38
# 3   89.0             1.0              270.0  2019-07-05               4.64
#
#    calculated_host_listings_count  availability_365
# ...

# %%
df3_isin = df3[df3["host_name"].isin(['Danielle', 'Ro'])].head()
df3_isin
#exact word
# Out:
#              id                                        name    host_id  \
# 559    205735.0                A Cozy Oasis in Bushwick, NY  1011426.0
# 710    260765.0          NewYork Modern Pre-War LoftStudio    480943.0
# 1064   444430.0             comfy room minutes from museums   420542.0
# 2906  1658703.0  Close to trains! Special long-term rates!!  8791051.0
# 3066  1807106.0            Stunning  Limestone  1 Bdrm Flat  9223085.0
#
#      host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 559   Danielle            Brooklyn         Bushwick  40.68364  -73.91076
# 710         Ro           Manhattan  Upper East Side  40.76928  -73.95021
# 1064  Danielle               Bronx       Mott Haven  40.81128  -73.92399
# 2906  Danielle            Brooklyn    East Flatbush  40.65260  -73.94999
# 3066  Danielle            Brooklyn    Crown Heights  40.67191  -73.93997
#
#             room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# #### 6.1.3. Using .contains( | )

# %%
df3_contains = df3[df3["host_name"].str.contains('Danielle|Ro')].head()
df3_contains
#contain them.
# Out:
#            id                              name    host_id    host_name  \
# 3      3831.0   Cozy Entire Floor of Brownstone     4869.0  LisaRoxanne
# 73    16974.0   SpaHa Loft: Enormous and Bright    65837.0        Robin
# 192   47362.0  LARGE, COMFY 1BDR W/CHARACTER!!!   214148.0       Robert
# 392  118061.0       Style in Stuyvesant Heights  2248897.0      Roberta
# 400  125163.0   Authentic New York City Living    622855.0       Rodney
#
#     neighbourhood_group       neighbourhood  latitude  longitude  \
# 3              Brooklyn        Clinton Hill  40.68514  -73.95976
# 73            Manhattan         East Harlem  40.80164  -73.93922
# 192            Brooklyn  Bedford-Stuyvesant  40.68237  -73.94150
# 392            Brooklyn  Bedford-Stuyvesant  40.68448  -73.92747
# 400            Brooklyn  Bedford-Stuyvesant  40.68569  -73.93038
#
#            room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### 6.2. By Index

# %% [markdown]
# #### 6.2.1. Retrieve Rows with Matching Index Values

# %% [raw]
# 6.1.2.1. using .loc[]

# %%
df4_modified = df3.set_index('neighbourhood')
df4_modified.head()
# Out:
#                    id                                              name  \
# neighbourhood
# Kensington     2539.0                Clean & quiet apt home by the park
# Midtown        2595.0                             Skylit Midtown Castle
# Clinton Hill   3831.0                   Cozy Entire Floor of Brownstone
# East Harlem    5022.0  Entire Apt: Spacious Studio/Loft by central park
# Murray Hill    5099.0         Large Cozy 1 BR Apartment In Midtown East
#
#                host_id    host_name neighbourhood_group  latitude  longitude  \
# neighbourhood
# Kensington      2787.0         John            Brooklyn  40.64749  -73.97237
# Midtown         2845.0     Jennifer           Manhattan  40.75362  -73.98377
# Clinton Hill    4869.0  LisaRoxanne            Brooklyn  40.68514  -73.95976
# East Harlem     7192.0        Laura           Manhattan  40.79851  -73.94399
# Murray Hill     7322.0        Chris           Manhattan  40.74767  -73.97500
#
# ...

# %%
df4_modified.loc[['Kensington','Midtown', 'Murray Hill' ]]
# Out:
#                        id                                            name  \
# neighbourhood
# Kensington         2539.0              Clean & quiet apt home by the park
# Kensington        63546.0                  Large and Cozy Private Bedroom
# Kensington       125594.0              SUPER BIG AND COZY PRIVATE BEDROOM
# Kensington       267652.0           Private clean pleasant spacious room.
# Kensington       282341.0             Kensington/Ditmas Park pied-a-terre
# ...                   ...                                             ...
# Murray Hill    35768121.0                              Murray Hill studio
# Murray Hill    35784049.0      Perfect NYC crib for Explorers & Travelers
# Murray Hill    35811237.0  Centrally located spacious 1-bedroom apartment
# Murray Hill    35916694.0     New Sophisticated 4BR/2.5BA NYC Midtown Apt
# Murray Hill    36081181.0   Private Room in the most convenient location!
#
# ...

# %% [raw]
# 5.1.2.2. using .iloc[]

# %%
df4_modified.iloc[10:15]
# Out:
#                      id                                              name  \
# neighbourhood
# Hell's Kitchen   5441.0                   Central Manhattan/near Broadway
# South Slope      5803.0    Lovely Room 1, Garden, Best Area, Legal rental
# Upper West Side  6021.0  Wonderful Guest Bedroom in Manhattan for SINGLES
# West Village     6090.0                     West Village Nest - Superhost
# Williamsburg     6848.0                  Only 2 stops to Manhattan studio
#
#                  host_id      host_name neighbourhood_group  latitude  \
# neighbourhood
# Hell's Kitchen    7989.0           Kate           Manhattan  40.76076
# South Slope       9744.0         Laurie            Brooklyn  40.66829
# Upper West Side  11528.0        Claudio           Manhattan  40.79826
# West Village     11975.0          Alina           Manhattan  40.73530
# Williamsburg     15991.0  Allen & Irina            Brooklyn  40.70837
#
# ...

# %% [markdown]
# ## 7. Sorting

# %%
df4.sort_values('price', ascending=False).head(6)
#from highest price
# Out:
#                                                     name neighbourhood_group  \
# 9155                 Furnished room in Astoria apartment              Queens
# 17696    Luxury 1 bedroom apt. -stunning Manhattan views            Brooklyn
# 12346                Quiet, Clean, Lit @ LES & Chinatown           Manhattan
# 6534                                  Spanish Harlem Apt           Manhattan
# 30273  Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho           Manhattan
# 4381                                       Film Location            Brooklyn
#
#          price
# 9155   10000.0
# 17696  10000.0
# 12346   9999.0
# 6534    9999.0
# 30273   8500.0
# 4381    8000.0

# %% [markdown]
# ## 8. Aggregating

# %% [markdown]
# ### 8.1. Group by

# %%
#group by
df4.groupby("neighbourhood_group").median().reset_index()
# Out:
#   neighbourhood_group  price
# 0               Bronx   65.0
# 1            Brooklyn   94.0
# 2           Manhattan  140.0
# 3              Queens   72.0
# 4       Staten Island   75.0

# %%
#group by
df4.groupby("neighbourhood_group").median()
# Out:
#                      price
# neighbourhood_group
# Bronx                 65.0
# Brooklyn              94.0
# Manhattan            140.0
# Queens                72.0
# Staten Island         75.0

# %% [raw]
# ---------------------------------------
